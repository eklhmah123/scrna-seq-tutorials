# %%
# !pip install anndata scanpy

import numpy as np
import pandas as pd
import anndata as ad
from scipy.sparse import csr_matrix
print(ad.__version__)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.6/176.6 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 66.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 106.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 96.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# ...

# %%
import numpy as np
import pandas as pd
import anndata as ad
import scanpy as sc
from scipy.sparse import csr_matrix

print(f"anndata version: {ad.__version__}")
print(f"scanpy version: {sc.__version__}")
print("All imports successful!")
# Out:
# anndata version: 0.12.10
# scanpy version: 1.12.1
# All imports successful!
# /tmp/ipykernel_7085/2182884543.py:7: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   print(f"anndata version: {ad.__version__}")
# /tmp/ipykernel_7085/2182884543.py:8: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print(f"scanpy version: {sc.__version__}")

# %%
counts = csr_matrix(np.random.poisson(1, size=(100, 2000)), dtype=np.float32)
adata = ad.AnnData(counts)
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000

# %%
print("AnnData object with n_obs x n_vars = 100 x 2000")
# Out:
# AnnData object with n_obs x n_vars = 100 x 2000

# %%
adata.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 126442 stored elements and shape (100, 2000)>

# %%
import scanpy as sc
import numpy as np

# Create a sparse matrix (example)
from scipy.sparse import csr_matrix
matrix = csr_matrix(np.random.rand(100, 2000))
print(matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 200000 stored elements and shape (100, 2000)>
#   Coords	Values
#   (0, 0)	0.2803881667569521
#   (0, 1)	0.5008023525155261
#   (0, 2)	0.590492833841825
#   (0, 3)	0.6179080841233668
#   (0, 4)	0.8417661756493678
#   (0, 5)	0.6132265241807046
#   (0, 6)	0.23046955177300676
#   (0, 7)	0.531960900634174
#   (0, 8)	0.06491929877614677
#   (0, 9)	0.3935899030279314
#   (0, 10)	0.9125532533694134
#   (0, 11)	0.8290891264669491
#   (0, 12)	0.958071031447093
#   (0, 13)	0.11865768219252748
#   (0, 14)	0.7489995462744212
#   (0, 15)	0.5619945027331277
#   (0, 16)	0.10039857085291448
#   (0, 17)	0.3305141309401378
#   (0, 18)	0.030668093721282652
#   (0, 19)	0.8360545387360606
#   (0, 20)	0.7776330891321166
#   (0, 21)	0.9332671069513817
#   (0, 22)	0.05922104662950978
#   (0, 23)	0.3262038968566374
#   (0, 24)	0.06261784153736238
#   :	:
#   (99, 1975)	0.2703469620695471
#   (99, 1976)	0.8441342932582685
# ...

# %%
adata.obs_names = [f"Cell_{i:d}" for i in range(adata.n_obs)]
adata.var_names = [f"Gene_{i:d}" for i in range(adata.n_vars)]
print(adata.obs_names[:10])
# Out:
# Index(['Cell_0', 'Cell_1', 'Cell_2', 'Cell_3', 'Cell_4', 'Cell_5', 'Cell_6',
#        'Cell_7', 'Cell_8', 'Cell_9'],
#       dtype='object')

# %%
import scanpy as sc
import pandas as pd

# Load your data
adata = sc.datasets.pbmc68k_reduced()

# This will show the index (the output you pasted)
print(adata.obs.index[:10])
# Out:
# Index(['AAAGCCTGGCTAAC-1', 'AAATTCGATGCACA-1', 'AACACGTGGTCTTT-1',
#        'AAGTGCACGTGCTA-1', 'ACACGAACGGAGTG-1', 'ACAGTTCTTAGCCA-1',
#        'ACATTCTGACTACG-1', 'ACCCTCGAGTGAGG-1', 'ACTGGCCTTTTCGT-1',
#        'ACTTGGGAACCAGT-1'],
#       dtype='object', name='index')

# %%
# Use actual cell names and actual gene names
adata[["AAAGCCTGGCTAAC-1", "AAGTGCACGTGCTA-1"], ["HES4", "TNFRSF4"]]
# Out:
# View of AnnData object with n_obs × n_vars = 2 × 2
#     obs: 'bulk_labels', 'n_genes', 'percent_mito', 'n_counts', 'S_score', 'G2M_score', 'phase', 'louvain'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'bulk_labels_colors', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
ct = np.random.choice(["B", "T", "Monocyte"], size=(adata.n_obs,))
adata.obs["cell_type"] = pd.Categorical(ct)  # Categoricals are preferred for efficiency
adata.obs
# Out:
#                       bulk_labels  n_genes  percent_mito  n_counts   S_score  \
# index
# AAAGCCTGGCTAAC-1   CD14+ Monocyte     1003      0.023856    2557.0 -0.119160
# AAATTCGATGCACA-1        Dendritic     1080      0.027458    2695.0  0.067026
# AACACGTGGTCTTT-1         CD56+ NK     1228      0.016819    3389.0 -0.147977
# AAGTGCACGTGCTA-1  CD4+/CD25 T Reg     1007      0.011797    2204.0  0.065216
# ACACGAACGGAGTG-1        Dendritic     1178      0.017277    3878.0 -0.122974
# ...                           ...      ...           ...       ...       ...
# TGGCACCTCCAACA-8        Dendritic     1166      0.008840    3733.0 -0.124456
# TGTGAGTGCTTTAC-8        Dendritic     1014      0.022068    2311.0 -0.298056
# TGTTACTGGCGATT-8  CD4+/CD25 T Reg     1079      0.012821    3354.0  0.216895
# TTCAGTACCGGGAA-8          CD19+ B     1030      0.014169    2823.0  0.139054
# TTGAGGTGGAGAGC-8        Dendritic     1552      0.010886    4685.0 -0.148449
#
# ...

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 700 × 765
#     obs: 'bulk_labels', 'n_genes', 'percent_mito', 'n_counts', 'S_score', 'G2M_score', 'phase', 'louvain', 'cell_type'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'bulk_labels_colors', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.obsm["X_umap"] = np.random.normal(0, 1, size=(adata.n_obs, 2))
adata.varm["gene_stuff"] = np.random.normal(0, 1, size=(adata.n_vars, 5))
adata.obsm
# Out:
# AxisArrays with keys: X_pca, X_umap

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 700 × 765
#     obs: 'bulk_labels', 'n_genes', 'percent_mito', 'n_counts', 'S_score', 'G2M_score', 'phase', 'louvain', 'cell_type'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'bulk_labels_colors', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs', 'gene_stuff'
#     obsp: 'connectivities', 'distances'

# %%
adata.uns["random"] = [1, 2, 3]
adata.uns
# Out:
# {'bulk_labels_colors': array(['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b',
#         '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'], dtype=object),
#  'louvain': {'params': {'random_state': array([0]), 'resolution': array([1])}},
#  'louvain_colors': array(['#023fa5', '#7d87b9', '#bec1d4', '#d6bcc0', '#bb7784', '#8e063b',
#         '#4a6fe3', '#8595e1', '#b5bbe3', '#e6afb9', '#e07b91'],
#        dtype=object),
#  'neighbors': {'params': {'method': 'umap', 'n_neighbors': array([10])}},
#  'pca': {'variance': array([30.928047 , 21.182432 , 14.686322 , 11.570731 ,  9.232856 ,
#           7.3497834,  4.338316 ,  3.197439 ,  3.1584399,  2.910167 ,
#           2.649945 ,  2.540031 ,  2.4057367,  2.3872852,  2.2644212,
#           2.2250588,  2.189688 ,  2.134691 ,  2.0775423,  2.0560663,
#           2.007874 ,  1.9969993,  1.9606696,  1.9441428,  1.9129871,
#           1.9063067,  1.8529838,  1.8260264,  1.7946786,  1.7489465,
# ...

# %%
adata.layers["log_transformed"] = np.log1p(adata.X)
adata
# Out:
# /tmp/ipykernel_7085/2818935080.py:1: RuntimeWarning: divide by zero encountered in log1p
#   adata.layers["log_transformed"] = np.log1p(adata.X)
# /tmp/ipykernel_7085/2818935080.py:1: RuntimeWarning: invalid value encountered in log1p
#   adata.layers["log_transformed"] = np.log1p(adata.X)
# AnnData object with n_obs × n_vars = 700 × 765
#     obs: 'bulk_labels', 'n_genes', 'percent_mito', 'n_counts', 'S_score', 'G2M_score', 'phase', 'louvain', 'cell_type'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'bulk_labels_colors', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups', 'random'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs', 'gene_stuff'
#     layers: 'log_transformed'
#     obsp: 'connectivities', 'distances'

# %%
adata.to_df(layer="log_transformed")
# Out:
# index                 HES4   TNFRSF4     SSU72     PARK7      RBP7       SRM  \
# index
# AAAGCCTGGCTAAC-1 -0.394525 -0.211956 -1.301953 -0.358105  1.478418 -0.757153
# AAATTCGATGCACA-1  0.775188 -0.211956  0.585005       NaN -0.191161 -0.757153
# AACACGTGGTCTTT-1 -0.394525 -0.211956  0.394067       NaN -0.191161 -0.757153
# AAGTGCACGTGCTA-1 -0.394525 -0.211956  0.757998 -0.170788 -0.191161 -0.757153
# ACACGAACGGAGTG-1 -0.394525 -0.211956 -1.301953 -0.933946 -0.191161 -0.757153
# ...                    ...       ...       ...       ...       ...       ...
# TGGCACCTCCAACA-8 -0.394525 -0.211956  0.316270 -0.877070 -0.191161  0.411447
# TGTGAGTGCTTTAC-8  1.426956 -0.211956 -1.301953       NaN -0.191161 -0.757153
# TGTTACTGGCGATT-8 -0.394525 -0.211956 -1.301953       NaN -0.191161  1.023889
# TTCAGTACCGGGAA-8 -0.394525 -0.211956 -1.301953 -0.487760 -0.191161 -0.757153
# TTGAGGTGGAGAGC-8 -0.394525 -0.211956  0.138021  0.566450 -0.191161  0.260825
#
# ...

# %%
adata.write('my_results.h5ad', compression="gzip")

# %%
# !apt-get install hdf5-tools

adata.write('my_results.h5ad', compression="gzip")

# !h5ls 'my_results.h5ad'
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   hdf5-tools
# 0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
# Need to get 347 kB of archives.
# After this operation, 1,255 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 hdf5-tools amd64 1.10.7+repack-4ubuntu2 [347 kB]
# Fetched 347 kB in 1s (250 kB/s)
# Selecting previously unselected package hdf5-tools.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../hdf5-tools_1.10.7+repack-4ubuntu2_amd64.deb ...
# Unpacking hdf5-tools (1.10.7+repack-4ubuntu2) ...
# Setting up hdf5-tools (1.10.7+repack-4ubuntu2) ...
# Processing triggers for man-db (2.10.2-1) ...
# X                        Dataset {700, 765}
# layers                   Group
# obs                      Group
# obsm                     Group
# ...

# %%
obs_meta = pd.DataFrame({
        'time_yr': np.random.choice([0, 2, 4, 8], adata.n_obs),
        'subject_id': np.random.choice(['subject 1', 'subject 2', 'subject 4', 'subject 8'], adata.n_obs),
        'instrument_type': np.random.choice(['type a', 'type b'], adata.n_obs),
        'site': np.random.choice(['site x', 'site y'], adata.n_obs),
    },
    index=adata.obs.index,    # these are the same IDs of observations as above!
)

# %%
adata = ad.AnnData(adata.X, obs=obs_meta, var=adata.var)

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 700 × 765
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 700 × 765
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'

# %%
adata[:5, ['HES4', 'TNFRSF4']]
# Out:
# View of AnnData object with n_obs × n_vars = 5 × 2
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'

# %%
# Use actual gene names from your data
adata_subset = adata[:5, ['HES4', 'SSU72']].copy()

# %%
# Replace 'Gene_1' with an actual gene name like 'HES4'
print(adata[:3, 'HES4'].X.toarray().tolist())
adata[:3, 'HES4'].X = [0, 0, 0]
print(adata[:3, 'HES4'].X.toarray().tolist())
# Out:
# [[-0.32600000500679016], [1.1710000038146973], [-0.32600000500679016]]
# [[0.0], [0.0], [0.0]]
# /usr/local/lib/python3.12/dist-packages/anndata/_core/anndata.py:630: FutureWarning: Setting element `.X` of view of `AnnData` object will obey copy-on-write semantics in the next minor release.
#   if self._handle_view_X_cow(value):
# /tmp/ipykernel_7085/916116967.py:3: ImplicitModificationWarning: Modifying `X` on a view results in data being overridden
#   adata[:3, 'HES4'].X = [0, 0, 0]

# %%
# Use actual gene names (replace with real names from your data)
adata_subset = adata[:3, ['HES4', 'TNFRSF4']]

# %%
adata_subset
# Out:
# View of AnnData object with n_obs × n_vars = 3 × 2
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'

# %%
adata_subset.obs['foo'] = range(3)
# Out:
# /tmp/ipykernel_7085/2955902014.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_subset.obs['foo'] = range(3)

# %%
adata_subset.obs['foo'] = range(3)

# %%
adata_subset
# Out:
# AnnData object with n_obs × n_vars = 3 × 2
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site', 'foo'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'

# %%
adata[adata.obs.time_yr.isin([2, 4])].obs.head()
# Out:
#                   time_yr subject_id instrument_type    site
# index
# AAATTCGATGCACA-1        4  subject 2          type a  site y
# AAGTGCACGTGCTA-1        2  subject 2          type b  site x
# ACAGTTCTTAGCCA-1        2  subject 8          type b  site y
# ACCCTCGAGTGAGG-1        4  subject 8          type b  site x
# ACTGGCCTTTTCGT-1        4  subject 8          type a  site x

# %%
import scanpy as sc
import anndata as ad

# Option 1: Using scanpy (recommended)
adata = sc.read('my_results.h5ad', backed='r')

# Option 2: Using anndata
adata = ad.read_h5ad('my_results.h5ad', backed='r')

# %%
adata.isbacked
# Out:
# True

# %%
adata.filename
# Out:
# PosixPath('my_results.h5ad')

# %%
adata.file.close()
